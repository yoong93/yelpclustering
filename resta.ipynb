# %%
##### Variables #####
K_CLUSTERS_RESTAURANT = 20
K_CLUSTERS_USER = 10
REDUCED_D = 300
TERMS_PER_CLUSTER_RESTAURANT = 5

# %%
# import libraries
from __future__ import print_function
from sklearn.decomposition import TruncatedSVD
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import Normalizer
from sklearn import metrics
from sklearn.cluster import MiniBatchKMeans
import logging
from time import time
import numpy as np
import sqlite3
import pandas as pd

# %matplotlib notebook
from matplotlib import pyplot as plt

# %%
# connect to database
conn = sqlite3.connect("yelp2.db")

# %%
# create a new dataframe, df ('user_id', 'business_id', 'stars', 'text' columns from review table)
df = pd.read_sql_query("select text, user_id, business_id, stars from review;", conn)

# %%
# user_id with >= 50 reviews
user_id_valcounts = df['user_id'].value_counts()
user_id_valcounts
# Out:
# bLbSNkLggFnqwNNzzq-Ijw    602
# PKEzKWv_FktMm2mGPjwd0Q    485
# UYcmGbelzRa0Q6JqzLoguw    410
# tH0uKD-vNwMoEc3Xk3Cbdg    329
# C2C0GPKvzWWnP57Os9eQ0w    324
# N3oNEwh0qgPqPP3Em6wJXw    316
# n86B7IkbU20AkxlFX_5aew    313
# U4INQZOPSUaj8hMjLlZ3KA    302
# 8DEyKVyplnOcSKx39vatbg    275
# qewG3X2O4X6JKskxyyqFwQ    257
# 3nDUQBjKyVor5wV0reJChg    257
# eZZyuJDouIg4p-GYB3PV_A    228
# 3nIuSCZk5f_2WWYMLN7h3w    217
# TdYKJgSgY2GF_YJnwsi5yQ    216
# YMgZqBUAddmFErxLtCfK_w    213
# L8P5OWO1Jh4B2HLa1Fnbng    212
# iSC96O2NjQc3JExGUHQG0Q    212
# JaqcCU3nxReTW2cBLHounA    209
# kmE8w5Y785eZmodsx0V6Ag    203
# _VMGbmIeK71rQGwOBWt_Kg    201
# y3FcL4bLy0eLlkb0SDPnBQ    200
# oeAhRa8yFa9jtrhaHnOyxQ    189
# B1829_hxXSEpDPEDJtYeIw    189
# FIk4lQQu1eTe2EpzQ4xhBA    185
# 8OeTLey-p-WaL9ErNEci1Q    183
# epkRB3J_oBEiyiwahvdmGg    183
# ZsUSGU1-L1ImomLZjXxxTg    180
# HJj82f-csBI7jjgenwqhvw    179
# hZfzVrhsCQ9JDAb2jYoJNQ    179
# 48vRThjhuhiSQINQ2KV8Sw    178
#                          ...
# YR8Jx240OaPMEWw7il01-w      1
# 4mP5AkBYhZ3teUkSG-Zkfw      1
# Ge-DjZHgOdLqja7GhfTHSg      1
# giJxhgnG-i10VHIDPJTS2Q      1
# Npr6u66YkKdyqh3AWMnJlg      1
# iqeD8ueIE4HwpywPPxLqtw      1
# Ar2oKgomNhaUk0PWoOHdRQ      1
# -A_wbFQ2ZhSYnPllAkG2TQ      1
# dsigYfF0MUXPX379Rpj54A      1
# bVtX8TaAmYCcTPqTmHCKMw      1
# ycpUGrN-3h57UsqJvQ5JjQ      1
# dfw6f-DKDXtz2Ds1j_CozQ      1
# MZuQLxzuGtmobRsD4YDq4w      1
# hYOFkluXCsir8aXJVSyGtQ      1
# 5kpeO5Ap-LfeunKY36DTRA      1
# ID6am45mRPHzTfQJ3F7Qyg      1
# 3HVilGJ4Zv7gs-jfOKxBGg      1
# wYBoTLSaEMxHFTVAaoxooQ      1
# y5qz_dHu832VDONRmJDhpA      1
# e4ixryFDvL3ugIDwB-dxtg      1
# ztF6hMa3-HeXa6Fm-BZ_KA      1
# 4yhHuaw20ZjxUNvbFAJSHQ      1
# rnAjuHO-_CwoNCqb-60MYA      1
# M-r4iKpiGONFh7SVN1IEtg      1
# SNclkukeUwI7Yw5UA3FTSQ      1
# itxag5iNwQqXZAN1SAgiBg      1
# 71DR2EUerdt6Tak2OKb3TA      1
# lIsoD9679f7SPdxJgUM70w      1
# lKc8szfZ-sLtg71OTOAavQ      1
# gJEUSpBJkbxh24YeHtkzXg      1
# Name: user_id, dtype: int64

# %%
# create a new dataframe, df2 (only include the data with user_id with >= 50 reviews)
top_users = user_id_valcounts[user_id_valcounts >= 50].index.tolist()
df2 = df[df['user_id'].isin(top_users)]
df2
# Out:
#                                                      text  \
# 5       I love love love Patisserie Manon!\n\nI was ex...
# 19      I had the pleasure of tasting a couple of thei...
# 22      Meep Meep!!\n\nThat was my first thought when ...
# 23      I came here on a saturday afternoon and got al...
# 28      Love this place.  The cakes and pastries are s...
# 31      I stopped by on their last day before their Su...
# 34      I really love their cassoulet and have had it ...
# 38      Their macarons are soo unique compared to othe...
# 42      I loved this place. I had the turkey, ham and ...
# 47      Cake, macaroons, and more oh my! This place is...
# 52      If I were to buy a birthday cake in Vegas, thi...
# 57      After bookmarking this place I had to try. \n\...
# 65      Are you French... no??  THEN SHUT UP!!!  Who r...
# 66      After being here multiple times I'd say it's a...
# 68      Patisserie manon - why are you 25mi from my ho...
# 72      Watch out bookmarks, I am beginning to blow th...
# 73      Picked up a loaf of bread and a couple yummy m...
# 77      A nice french bakery, pastry, and bistro on th...
# 91      Looks like our search for good French Macrons ...
# 102     ETHNIC BAKERY TOUR  #2-FRANCE\n\nI have been a...
# 103     As someone who loves macarons and French cuisi...
# 105     This was down the street from our house and no...
# 106     This place is so sweet. I love it. \n\nI am ha...
# 109     Great place.  I hope it makes it.  I've sample...
# 116     I wish this place was closer!  Then again, wou...
# 129     Oh, you had me at French Macaron!\n\nI was ple...
# 131     I've been twice to pick up treasures and bring...
# 132     Hit Manon several times since my January revie...
# 133     Yelp 100 Challenge * 19/100\n\nYes, you can be...
# 134     Merci Beaucoup Patisserie Manon for the 15% Mi...
# ...                                                   ...
# 634755  I'm originally from NE Ohio and I'd never seen...
# 634771  I love me some Chipotle, and this place is pre...
# 634774  DISCLAIMER: This review is based on one and on...
# 634776  The place is clean.  Prices are always decent....
# 634823  New York-New York and pizza go together like a...
# 634829  I'm actually a bit surprised at all the negati...
# 634861  This place is good if you want a quick and che...
# 634868  One of the few places open late. There were tw...
# 634903  I was surprised by how good this pizza really ...
# 634969  This place is in a casino for a reason. It's a...
# 634996  Who doesn't love grabbing a slice of greasy ne...
# 635014  Pizza Rock is cool, but Little Tony's is even ...
# 635021  We really enjoy the fresh menu options. The th...
# 635024  Looking for that delicious Pizza Rock pizza bu...
# 635027  Excellent service, great Caesar salad, lasagna...
# 635028  Been here a couple times since opening date & ...
# 635030  I wanted to try Little Tony's based on Yelp re...
# 635051  Found this gem from Groupon! Amazing food and ...
# 635058  Since I still haven't properly tried Pizza Roc...
# 635067  Had to try the pizza Champs pie. Went for lunc...
# 635074  Ever had a "mouth-gasm?" I have. And it happen...
# 635075  If you happen to find yourself in Palace Stati...
# 635076  I am a fan of Pizza Rock and when I had the op...
# 635091  Went here with the Fiancee and I haven't laugh...
# 635111  Tony's pizza is the best and now I get to enjo...
# 635118  Update to my review. \n\nStill an excellent pi...
# 635126  My first time eating here so I ordered a few t...
# 635132  This spot wasn't even on my radar til it was f...
# 635139  Since this is owned by the same people who own...
# 635144  The Skinny update: skip the Dillinger - the "w...
#
#                        user_id             business_id  stars
# 5       -594af_E7Z9VVjQc9pJK3g  A0X1baHPgw9IiBRivu0G9g    5.0
# 19      TdYKJgSgY2GF_YJnwsi5yQ  A0X1baHPgw9IiBRivu0G9g    4.0
# 22      y3FcL4bLy0eLlkb0SDPnBQ  A0X1baHPgw9IiBRivu0G9g    5.0
# 23      rHgT6lBbZ2PaHt0UWfTMtw  A0X1baHPgw9IiBRivu0G9g    5.0
# 28      FIk4lQQu1eTe2EpzQ4xhBA  A0X1baHPgw9IiBRivu0G9g    5.0
# 31      k4M43lXJuQMpQW65DTqzIQ  A0X1baHPgw9IiBRivu0G9g    4.0
# 34      7HOTOydGS7wJYaJqNoDfeg  A0X1baHPgw9IiBRivu0G9g    4.0
# 38      5OllWsrKJsYo3XQK6siRKA  A0X1baHPgw9IiBRivu0G9g    5.0
# 42      _i3IZYU28R3xgV4hxkmKjw  A0X1baHPgw9IiBRivu0G9g    5.0
# 47      fxrQSMhHlBv6eJVRdchG9Q  A0X1baHPgw9IiBRivu0G9g    5.0
# 52      Apj8bnqWlnaiSu4YDl0wDA  A0X1baHPgw9IiBRivu0G9g    4.0
# 57      iS4NVHLQDt1IzmmMKqwy5A  A0X1baHPgw9IiBRivu0G9g    4.0
# 65      jX7n6KfNZ22kBh6AHhxRbA  A0X1baHPgw9IiBRivu0G9g    5.0
# 66      3MO--ENqKScLFQFuW1751g  A0X1baHPgw9IiBRivu0G9g    3.0
# 68      dsaj_eA71FvpUh49zzKcGA  A0X1baHPgw9IiBRivu0G9g    5.0
# 72      N3oNEwh0qgPqPP3Em6wJXw  A0X1baHPgw9IiBRivu0G9g    5.0
# 73      0KeT9NKimYkHN0wlrij-dg  A0X1baHPgw9IiBRivu0G9g    4.0
# 77      Ksp1e9Dw0Jcog_ZBD3-45g  A0X1baHPgw9IiBRivu0G9g    4.0
# 91      77lef7kKkoOVupY-7AmieQ  A0X1baHPgw9IiBRivu0G9g    5.0
# 102     3nDUQBjKyVor5wV0reJChg  A0X1baHPgw9IiBRivu0G9g    4.0
# 103     tH0uKD-vNwMoEc3Xk3Cbdg  A0X1baHPgw9IiBRivu0G9g    4.0
# 105     VZRxANvyTm2ixS6jYDGgEw  A0X1baHPgw9IiBRivu0G9g    5.0
# 106     hZfzVrhsCQ9JDAb2jYoJNQ  A0X1baHPgw9IiBRivu0G9g    5.0
# 109     qbq4zC9SrZuaQ4-J-wtRuw  A0X1baHPgw9IiBRivu0G9g    4.0
# 116     b_9bJ2YjHbbvAob56f6U7A  A0X1baHPgw9IiBRivu0G9g    5.0
# 129     UYcmGbelzRa0Q6JqzLoguw  A0X1baHPgw9IiBRivu0G9g    5.0
# 131     DPtOaWemjBPvFiZJBi0m8A  A0X1baHPgw9IiBRivu0G9g    4.0
# 132     N044aCKJv3G5WuvwT5AJcA  A0X1baHPgw9IiBRivu0G9g    4.0
# 133     QJMOgjRYeogK43kyfX6PKw  A0X1baHPgw9IiBRivu0G9g    4.0
# 134     uEvusDwoSymbJJ0auR3muQ  A0X1baHPgw9IiBRivu0G9g    5.0
# ...                        ...                     ...    ...
# 634755  6w6pXL1N1q9RkmG6b4Su6g  rD32POdIhGN9eR8aUxl-3A    4.0
# 634771  njUgJcn8ZN0BdZdNEswRwA  rD32POdIhGN9eR8aUxl-3A    4.0
# 634774  Ae4uXwFHp-5fGrt6OONaXw  rD32POdIhGN9eR8aUxl-3A    3.0
# 634776  a0PH_2zKVQExMP5w-OJQKw  rD32POdIhGN9eR8aUxl-3A    3.0
# 634823  0tvCcnfJnSs55iB6mqPk3w  fXSOxjL7FP_sVew1gXnOIw    3.0
# 634829  KFZISl5mOUJ6bu3qCUrO-g  fXSOxjL7FP_sVew1gXnOIw    3.0
# 634861  48vRThjhuhiSQINQ2KV8Sw  fXSOxjL7FP_sVew1gXnOIw    3.0
# 634868  bULBMkGqXU2xjFuPL-3JgQ  fXSOxjL7FP_sVew1gXnOIw    1.0
# 634903  3rsZCoTmr8EM7DwtGm_RsQ  fXSOxjL7FP_sVew1gXnOIw    4.0
# 634969  3Vd_ATdvvuVVgn_YCpz8fw  fXSOxjL7FP_sVew1gXnOIw    2.0
# 634996  qPVtjjp8sNQ32p9860SR9Q  fXSOxjL7FP_sVew1gXnOIw    3.0
# 635014  _pMzR6yoPbU98t-NH8TZ3w  Z0o7EnCj3fgzC7E3QRabhQ    5.0
# 635021  KrT4LHYdRt-m1DMPtVKN4w  Z0o7EnCj3fgzC7E3QRabhQ    5.0
# 635024  1dWLN4Mr4hKhu8MQUCKqXQ  Z0o7EnCj3fgzC7E3QRabhQ    4.0
# 635027  xNKjIktegMyHVSXFznJTRg  Z0o7EnCj3fgzC7E3QRabhQ    5.0
# 635028  8Ox2EA8A7FVSzVEM3TRn7Q  Z0o7EnCj3fgzC7E3QRabhQ    5.0
# 635030  m-BZLIIh5PCAKnzH0qj_0Q  Z0o7EnCj3fgzC7E3QRabhQ    4.0
# 635051  NFodPTpbWK7dSymxaBiUXg  Z0o7EnCj3fgzC7E3QRabhQ    5.0
# 635058  _VMGbmIeK71rQGwOBWt_Kg  Z0o7EnCj3fgzC7E3QRabhQ    4.0
# 635067  8fsZcLADFrPTbGrFqMACpg  Z0o7EnCj3fgzC7E3QRabhQ    4.0
# 635074  JYcCYNWs8Ul6ewG5kCYW4Q  Z0o7EnCj3fgzC7E3QRabhQ    5.0
# 635075  dwl0NrgPtTZWT_AKJ0ezjQ  Z0o7EnCj3fgzC7E3QRabhQ    5.0
# 635076  rKkpHJkJ27xOwnhy_bMkvA  Z0o7EnCj3fgzC7E3QRabhQ    3.0
# 635091  y1b_9KmwNUWG1AS3CazFLA  Z0o7EnCj3fgzC7E3QRabhQ    5.0
# 635111  r52bugu98l77gdqTnIJ2oQ  Z0o7EnCj3fgzC7E3QRabhQ    5.0
# 635118  -EJorVxe7h2GSxdiRyMmDA  Z0o7EnCj3fgzC7E3QRabhQ    1.0
# 635126  eynu0uJEon1ORH1nIf4pTA  Z0o7EnCj3fgzC7E3QRabhQ    3.0
# 635132  bLbSNkLggFnqwNNzzq-Ijw  Z0o7EnCj3fgzC7E3QRabhQ    4.0
# 635139  eh9uc8xHYR9-rki7fWggQQ  Z0o7EnCj3fgzC7E3QRabhQ    4.0
# 635144  h9RUaaHa5kcQKqtJ-sgS0Q  Z0o7EnCj3fgzC7E3QRabhQ    4.0
#
# [49346 rows x 4 columns]

# %%
df2.head()
# Out:
#                                                  text                 user_id  \
# 5   I love love love Patisserie Manon!\n\nI was ex...  -594af_E7Z9VVjQc9pJK3g
# 19  I had the pleasure of tasting a couple of thei...  TdYKJgSgY2GF_YJnwsi5yQ
# 22  Meep Meep!!\n\nThat was my first thought when ...  y3FcL4bLy0eLlkb0SDPnBQ
# 23  I came here on a saturday afternoon and got al...  rHgT6lBbZ2PaHt0UWfTMtw
# 28  Love this place.  The cakes and pastries are s...  FIk4lQQu1eTe2EpzQ4xhBA
#
#                business_id  stars
# 5   A0X1baHPgw9IiBRivu0G9g    5.0
# 19  A0X1baHPgw9IiBRivu0G9g    4.0
# 22  A0X1baHPgw9IiBRivu0G9g    5.0
# 23  A0X1baHPgw9IiBRivu0G9g    5.0
# 28  A0X1baHPgw9IiBRivu0G9g    5.0

# %%
dict_business= {}
for index, row in df2.iterrows():
    business = str(row['business_id'])
    user = str(row ['user_id'])
    review = str(row['text']).replace('\n','')
    if business in dict_business:
        dict_business[business] += review
    else:
        dict_business[business] = review	
        
#dict_business.items()

rawdata_busi = [ [k2,v2] for k2, v2 in dict_business.items() ]

# %%
print('number of unique users: ', len(top_users))
unique_business = list(set(df2['business_id']))
print('number of unique restaurants: ', len(unique_business))
# Out:
# number of unique users:  558
# number of unique restaurants:  1620

# %%
# we are now left with 49,346 review texts data
len(df2)
# Out:
# 49346

# %%
from stop_words import get_stop_words
en_stop = get_stop_words('en')

# %%
data_b=[]

for entry in rawdata_busi:
    nonstop = []
    for word in entry[1].split():
        if word not in en_stop:
            nonstop.append(word)
    stopresult = ' '.join(nonstop)
    entry[1] = stopresult
    data_b.append(stopresult)

# %%
# extract features from review texts
MAX_FEATURES = 100000

print("Extracting features from the training dataset using a sparse vectorizer")
t0 = time()
vectorizer = TfidfVectorizer(max_df=0.7, max_features=MAX_FEATURES,
                             min_df=100, stop_words='english',
                             use_idf=True)

# X is a sparse matrix of size 49346 * 4039
X = vectorizer.fit_transform(data_b)

print("done in %fs" % (time() - t0))
print("n_samples: %d, n_features: %d" % X.shape)
# Out:
# Extracting features from the training dataset using a sparse vectorizer
# done in 4.851238s
# n_samples: 1620, n_features: 3186

# %%
len(data_b)
# Out:
# 1620

# %%
X.shape
# Out:
# (1620, 3186)

# %%
# reduce dimensionality from 4039 to 200
print("Performing dimensionality reduction using LSA")
t0 = time()
svd = TruncatedSVD(REDUCED_D)
normalizer = Normalizer(copy=False)
lsa = make_pipeline(svd, normalizer)
lsa_X = lsa.fit_transform(X)
lsa_X
print("done in %fs" % (time() - t0))
print("(Reduced) n_samples: %d, n_features: %d" % lsa_X.shape)

explained_variance = svd.explained_variance_ratio_.sum()
print("Explained variance of the SVD step: {}%".format(
    int(explained_variance * 100)))
# Out:
# Performing dimensionality reduction using LSA
# done in 4.426687s
# (Reduced) n_samples: 1620, n_features: 300
# Explained variance of the SVD step: 78%

# %%
# train a k means classifier with K_CLUSTERS_RESTAURANT
from operator import itemgetter
#K_CLUSTERS_RESTAURANT = sorted(accuracy_rc, key=itemgetter(1))[-1][0] # k with best score
km = MiniBatchKMeans(n_clusters=K_CLUSTERS_RESTAURANT, init='k-means++', n_init=5,
                     init_size=100000, batch_size=1000, verbose=True)
km.fit(lsa_X)
# Out:
# Init 1/5 with method: k-means++
# Inertia for init 1/5: 898.607737
# Init 2/5 with method: k-means++
# Inertia for init 2/5: 914.954502
# Init 3/5 with method: k-means++
# Inertia for init 3/5: 899.928533
# Init 4/5 with method: k-means++
# Inertia for init 4/5: 909.310215
# Init 5/5 with method: k-means++
# Inertia for init 5/5: 905.608499
# Minibatch iteration 1/200: mean batch inertia: 0.557139, ewa inertia: 0.557139
# Minibatch iteration 2/200: mean batch inertia: 0.556282, ewa inertia: 0.556282
# Minibatch iteration 3/200: mean batch inertia: 0.548330, ewa inertia: 0.548330
# Minibatch iteration 4/200: mean batch inertia: 0.562108, ewa inertia: 0.562108
# Minibatch iteration 5/200: mean batch inertia: 0.552741, ewa inertia: 0.552741
# Minibatch iteration 6/200: mean batch inertia: 0.551367, ewa inertia: 0.551367
# Minibatch iteration 7/200: mean batch inertia: 0.543624, ewa inertia: 0.543624
# Minibatch iteration 8/200: mean batch inertia: 0.543977, ewa inertia: 0.543977
# Minibatch iteration 9/200: mean batch inertia: 0.544214, ewa inertia: 0.544214
# Minibatch iteration 10/200: mean batch inertia: 0.546464, ewa inertia: 0.546464
# Minibatch iteration 11/200: mean batch inertia: 0.549881, ewa inertia: 0.549881
# Minibatch iteration 12/200: mean batch inertia: 0.533925, ewa inertia: 0.533925
# Minibatch iteration 13/200: mean batch inertia: 0.540030, ewa inertia: 0.540030
# Minibatch iteration 14/200: mean batch inertia: 0.545047, ewa inertia: 0.545047
# Minibatch iteration 15/200: mean batch inertia: 0.547705, ewa inertia: 0.547705
# Minibatch iteration 16/200: mean batch inertia: 0.537072, ewa inertia: 0.537072
# Minibatch iteration 17/200: mean batch inertia: 0.541765, ewa inertia: 0.541765
# Minibatch iteration 18/200: mean batch inertia: 0.539422, ewa inertia: 0.539422
# Minibatch iteration 19/200: mean batch inertia: 0.534458, ewa inertia: 0.534458
# Minibatch iteration 20/200: mean batch inertia: 0.542807, ewa inertia: 0.542807
# Minibatch iteration 21/200: mean batch inertia: 0.536900, ewa inertia: 0.536900
# Minibatch iteration 22/200: mean batch inertia: 0.543028, ewa inertia: 0.543028
# Converged (lack of improvement in inertia) at iteration 22/200
# Computing label assignment and total inertia
# MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=100000, max_iter=100, max_no_improvement=10,
#         n_clusters=20, n_init=5, random_state=None,
#         reassignment_ratio=0.01, tol=0.0, verbose=True)

# %%
# result
print("Top %d terms per cluster:" %TERMS_PER_CLUSTER_RESTAURANT)
original_space_centroids = svd.inverse_transform(km.cluster_centers_)
order_centroids = original_space_centroids.argsort()[:, ::-1]
terms = vectorizer.get_feature_names()
for i in range(K_CLUSTERS_RESTAURANT):
    print("Cluster %d:" % i, end='')
    for ind in order_centroids[i, :TERMS_PER_CLUSTER_RESTAURANT]:
        print(' %s' % terms[ind], end='')
    print()
# Out:
# Top 5 terms per cluster:
# Cluster 0: thai pad curry rice spicy
# Cluster 1: italian pasta bread wine dish
# Cluster 2: sushi roll rolls ayce nigiri
# Cluster 3: pizza crust pizzas pepperoni toppings
# Cluster 4: buffet buffets station legs crab
# Cluster 5: mexican salsa burrito chips beans
# Cluster 6: wings wing boneless buffalo fries
# Cluster 7: chinese rice noodles soup boba
# Cluster 8: burger fries burgers bacon shake
# Cluster 9: breakfast eggs pancakes toast hash
# Cluster 10: beer bar beers pub hour
# Cluster 11: tacos taco asada salsa carne
# Cluster 12: pita hummus greek mediterranean lamb
# Cluster 13: sandwich coffee sandwiches bread deli
# Cluster 14: fries casino dog burger bar
# Cluster 15: steak steakhouse filet lobster steaks
# Cluster 16: pho vietnamese broth rolls pork
# Cluster 17: bbq korean ribs brisket pork
# Cluster 18: shrimp rice ramen crab pasta
# Cluster 19: smoothie healthy juice wrap protein

# %%
from collections import Counter
clusters = km.labels_.tolist()
print(Counter(clusters))
# Out:
# Counter({18: 177, 1: 159, 14: 133, 2: 113, 3: 108, 9: 103, 7: 90, 15: 84, 8: 78, 10: 77, 5: 72, 13: 68, 17: 66, 4: 61, 0: 57, 12: 48, 11: 45, 16: 30, 19: 30, 6: 21})

# %%
# add a column 'cluster' to the existing dataframe 
clusters = km.labels_.tolist()
print(len(clusters))
df2.head()
# Out:
# 1620
#                                                  text                 user_id  \
# 5   I love love love Patisserie Manon!\n\nI was ex...  -594af_E7Z9VVjQc9pJK3g
# 19  I had the pleasure of tasting a couple of thei...  TdYKJgSgY2GF_YJnwsi5yQ
# 22  Meep Meep!!\n\nThat was my first thought when ...  y3FcL4bLy0eLlkb0SDPnBQ
# 23  I came here on a saturday afternoon and got al...  rHgT6lBbZ2PaHt0UWfTMtw
# 28  Love this place.  The cakes and pastries are s...  FIk4lQQu1eTe2EpzQ4xhBA
#
#                business_id  stars
# 5   A0X1baHPgw9IiBRivu0G9g    5.0
# 19  A0X1baHPgw9IiBRivu0G9g    4.0
# 22  A0X1baHPgw9IiBRivu0G9g    5.0
# 23  A0X1baHPgw9IiBRivu0G9g    5.0
# 28  A0X1baHPgw9IiBRivu0G9g    5.0

# %%
df2.insert(len(df2.columns),'cluster',0)
df2.head(1000)
# Out:
#                                                     text  \
# 5      I love love love Patisserie Manon!\n\nI was ex...
# 19     I had the pleasure of tasting a couple of thei...
# 22     Meep Meep!!\n\nThat was my first thought when ...
# 23     I came here on a saturday afternoon and got al...
# 28     Love this place.  The cakes and pastries are s...
# 31     I stopped by on their last day before their Su...
# 34     I really love their cassoulet and have had it ...
# 38     Their macarons are soo unique compared to othe...
# 42     I loved this place. I had the turkey, ham and ...
# 47     Cake, macaroons, and more oh my! This place is...
# 52     If I were to buy a birthday cake in Vegas, thi...
# 57     After bookmarking this place I had to try. \n\...
# 65     Are you French... no??  THEN SHUT UP!!!  Who r...
# 66     After being here multiple times I'd say it's a...
# 68     Patisserie manon - why are you 25mi from my ho...
# 72     Watch out bookmarks, I am beginning to blow th...
# 73     Picked up a loaf of bread and a couple yummy m...
# 77     A nice french bakery, pastry, and bistro on th...
# 91     Looks like our search for good French Macrons ...
# 102    ETHNIC BAKERY TOUR  #2-FRANCE\n\nI have been a...
# 103    As someone who loves macarons and French cuisi...
# 105    This was down the street from our house and no...
# 106    This place is so sweet. I love it. \n\nI am ha...
# 109    Great place.  I hope it makes it.  I've sample...
# 116    I wish this place was closer!  Then again, wou...
# 129    Oh, you had me at French Macaron!\n\nI was ple...
# 131    I've been twice to pick up treasures and bring...
# 132    Hit Manon several times since my January revie...
# 133    Yelp 100 Challenge * 19/100\n\nYes, you can be...
# 134    Merci Beaucoup Patisserie Manon for the 15% Mi...
# ...                                                  ...
# 11738  the best breakfast place i've been to in my 27...
# 11747  Service is absolutely horrible here. Had to fl...
# 11764  2nd time here and I don't think we'll be back....
# 11768  The portions here are huge, but the food is ta...
# 11789  Before hitting up Marquee Night Club (on Party...
# 11806  Holstein's is a great option! \n\nIt's definit...
# 11817  Updating once again based on experiencing the ...
# 11834  5 stars for the food, 2 stars for the service....
# 11873  Hello Lobster Mac N Cheese you are my friend! ...
# 11885  I am debating between giving this place a 3 or...
# 11904  Rule No. 1:  Don't piss me off before I even g...
# 11942  Love Holsteins! Every time we plan a party nig...
# 11951  This place was packed at 5pm on a Saturday eve...
# 11959  Late night shake craving brought me in. It was...
# 11990  Oh my god. I've been wanting to try this for a...
# 11995  (Also located in Imperial Palace and M-Resort)...
# 11998  Came in for an early dinner since on was on th...
# 12001  Had the chicken and waffles, and it was not as...
# 12010  I'm not understanding the rave reviews of the ...
# 12024  "Beast Warrior Proportions".\n\nThat's the bes...
# 12048  When God appointed Gluttony as a sin. He was e...
# 12068  I've been to this place nearly a dozen times a...
# 12082  A cardinal sin was committed at Holsteins: I d...
# 12092  It all started with The Drunken Monkey which p...
# 12095  Talk about gourmet burger! Very creative conce...
# 12102  Kinda on the fence, but for now I will give 3 ...
# 12165  Being a restaurant at The Cosmopolitan I had p...
# 12180  Another featured burger in the "Vegas Seven" M...
# 12182  Wow!!!  Yummy burgers and delicious adult shak...
# 12184  Stopped by here for dinner after finding it im...
#
#                       user_id             business_id  stars  cluster
# 5      -594af_E7Z9VVjQc9pJK3g  A0X1baHPgw9IiBRivu0G9g    5.0        0
# 19     TdYKJgSgY2GF_YJnwsi5yQ  A0X1baHPgw9IiBRivu0G9g    4.0        0
# 22     y3FcL4bLy0eLlkb0SDPnBQ  A0X1baHPgw9IiBRivu0G9g    5.0        0
# 23     rHgT6lBbZ2PaHt0UWfTMtw  A0X1baHPgw9IiBRivu0G9g    5.0        0
# 28     FIk4lQQu1eTe2EpzQ4xhBA  A0X1baHPgw9IiBRivu0G9g    5.0        0
# 31     k4M43lXJuQMpQW65DTqzIQ  A0X1baHPgw9IiBRivu0G9g    4.0        0
# 34     7HOTOydGS7wJYaJqNoDfeg  A0X1baHPgw9IiBRivu0G9g    4.0        0
# 38     5OllWsrKJsYo3XQK6siRKA  A0X1baHPgw9IiBRivu0G9g    5.0        0
# 42     _i3IZYU28R3xgV4hxkmKjw  A0X1baHPgw9IiBRivu0G9g    5.0        0
# 47     fxrQSMhHlBv6eJVRdchG9Q  A0X1baHPgw9IiBRivu0G9g    5.0        0
# 52     Apj8bnqWlnaiSu4YDl0wDA  A0X1baHPgw9IiBRivu0G9g    4.0        0
# 57     iS4NVHLQDt1IzmmMKqwy5A  A0X1baHPgw9IiBRivu0G9g    4.0        0
# 65     jX7n6KfNZ22kBh6AHhxRbA  A0X1baHPgw9IiBRivu0G9g    5.0        0
# 66     3MO--ENqKScLFQFuW1751g  A0X1baHPgw9IiBRivu0G9g    3.0        0
# 68     dsaj_eA71FvpUh49zzKcGA  A0X1baHPgw9IiBRivu0G9g    5.0        0
# 72     N3oNEwh0qgPqPP3Em6wJXw  A0X1baHPgw9IiBRivu0G9g    5.0        0
# 73     0KeT9NKimYkHN0wlrij-dg  A0X1baHPgw9IiBRivu0G9g    4.0        0
# 77     Ksp1e9Dw0Jcog_ZBD3-45g  A0X1baHPgw9IiBRivu0G9g    4.0        0
# 91     77lef7kKkoOVupY-7AmieQ  A0X1baHPgw9IiBRivu0G9g    5.0        0
# 102    3nDUQBjKyVor5wV0reJChg  A0X1baHPgw9IiBRivu0G9g    4.0        0
# 103    tH0uKD-vNwMoEc3Xk3Cbdg  A0X1baHPgw9IiBRivu0G9g    4.0        0
# 105    VZRxANvyTm2ixS6jYDGgEw  A0X1baHPgw9IiBRivu0G9g    5.0        0
# 106    hZfzVrhsCQ9JDAb2jYoJNQ  A0X1baHPgw9IiBRivu0G9g    5.0        0
# 109    qbq4zC9SrZuaQ4-J-wtRuw  A0X1baHPgw9IiBRivu0G9g    4.0        0
# 116    b_9bJ2YjHbbvAob56f6U7A  A0X1baHPgw9IiBRivu0G9g    5.0        0
# 129    UYcmGbelzRa0Q6JqzLoguw  A0X1baHPgw9IiBRivu0G9g    5.0        0
# 131    DPtOaWemjBPvFiZJBi0m8A  A0X1baHPgw9IiBRivu0G9g    4.0        0
# 132    N044aCKJv3G5WuvwT5AJcA  A0X1baHPgw9IiBRivu0G9g    4.0        0
# 133    QJMOgjRYeogK43kyfX6PKw  A0X1baHPgw9IiBRivu0G9g    4.0        0
# 134    uEvusDwoSymbJJ0auR3muQ  A0X1baHPgw9IiBRivu0G9g    5.0        0
# ...                       ...                     ...    ...      ...
# 11738  Nw6Jza_cb0aqd4PT769Vzw  g8OnV26ywJlZpezdBnOWUQ    3.0        0
# 11747  -ouzfV5nm0Fmv3JRLXegmQ  g8OnV26ywJlZpezdBnOWUQ    2.0        0
# 11764  0KeT9NKimYkHN0wlrij-dg  g8OnV26ywJlZpezdBnOWUQ    2.0        0
# 11768  zBi_JWB5uUdVuz3JLoAxGQ  g8OnV26ywJlZpezdBnOWUQ    4.0        0
# 11789  oDyEexUT09e3XhxIp0-Wxg  P7pxQFqr7yBKMMI2J51udw    4.0        0
# 11806  6NYDXzkyYW3O2zYjzPRMsg  P7pxQFqr7yBKMMI2J51udw    4.0        0
# 11817  hZfzVrhsCQ9JDAb2jYoJNQ  P7pxQFqr7yBKMMI2J51udw    5.0        0
# 11834  c2MQ_LPuvtiiKFR_-OY9pg  P7pxQFqr7yBKMMI2J51udw    2.0        0
# 11873  8QKrhvVqhEkD8xo4E4s0GQ  P7pxQFqr7yBKMMI2J51udw    4.0        0
# 11885  UYcmGbelzRa0Q6JqzLoguw  P7pxQFqr7yBKMMI2J51udw    4.0        0
# 11904  m-BZLIIh5PCAKnzH0qj_0Q  P7pxQFqr7yBKMMI2J51udw    4.0        0
# 11942  z8wN6EQuw_JF-zTjcNgsLw  P7pxQFqr7yBKMMI2J51udw    5.0        0
# 11951  YVQFzWm0H72mLUh-8gzd5w  P7pxQFqr7yBKMMI2J51udw    3.0        0
# 11959  o4tYl3Hz0oDfpNn4k02DCw  P7pxQFqr7yBKMMI2J51udw    4.0        0
# 11990  Nhk0jTP2gkU12G4LHJVR3A  g8OnV26ywJlZpezdBnOWUQ    5.0        0
# 11995  hkSiQAfl6w3882JJQzRTlQ  g8OnV26ywJlZpezdBnOWUQ    5.0        0
# 11998  o4tYl3Hz0oDfpNn4k02DCw  g8OnV26ywJlZpezdBnOWUQ    3.0        0
# 12001  VZRxANvyTm2ixS6jYDGgEw  g8OnV26ywJlZpezdBnOWUQ    2.0        0
# 12010  qbq4zC9SrZuaQ4-J-wtRuw  g8OnV26ywJlZpezdBnOWUQ    2.0        0
# 12024  H3wPBzQCKCKiHcV7GZK4kg  g8OnV26ywJlZpezdBnOWUQ    5.0        0
# 12048  UvY0E6Wuhv_0Bita52RPOw  g8OnV26ywJlZpezdBnOWUQ    4.0        0
# 12068  kmE8w5Y785eZmodsx0V6Ag  P7pxQFqr7yBKMMI2J51udw    4.0        0
# 12082  ugNQV0isqQSAuuGzoK87sQ  P7pxQFqr7yBKMMI2J51udw    4.0        0
# 12092  Sv48jgljDP-CRfXmU8uSgA  P7pxQFqr7yBKMMI2J51udw    3.0        0
# 12095  Nbr4DYLPxURjxelLVTSt8A  P7pxQFqr7yBKMMI2J51udw    4.0        0
# 12102  SfY0jEFqBkrqq9bVi6P31Q  P7pxQFqr7yBKMMI2J51udw    3.0        0
# 12165  hulIBBzPsCaQDcoh_JgSBA  P7pxQFqr7yBKMMI2J51udw    1.0        0
# 12180  mY3mROf28N-vY1fpR-FFUw  P7pxQFqr7yBKMMI2J51udw    3.0        0
# 12182  1dWLN4Mr4hKhu8MQUCKqXQ  P7pxQFqr7yBKMMI2J51udw    4.0        0
# 12184  iAevEfcmtCr2cpd6IRqnTA  P7pxQFqr7yBKMMI2J51udw    4.0        0
#
# [1000 rows x 5 columns]

# %%
for index, row  in df2.iterrows():
    bid = str(row['business_id'])
    ind = -1
    for i in range(0, len(rawdata_busi)):
        if(bid == str(rawdata_busi[i][0])):
            ind = i
    df2.set_value(index, 'cluster', clusters[ind])

# %%
df2.head(1000)
# Out:
#                                                     text  \
# 5      I love love love Patisserie Manon!\n\nI was ex...
# 19     I had the pleasure of tasting a couple of thei...
# 22     Meep Meep!!\n\nThat was my first thought when ...
# 23     I came here on a saturday afternoon and got al...
# 28     Love this place.  The cakes and pastries are s...
# 31     I stopped by on their last day before their Su...
# 34     I really love their cassoulet and have had it ...
# 38     Their macarons are soo unique compared to othe...
# 42     I loved this place. I had the turkey, ham and ...
# 47     Cake, macaroons, and more oh my! This place is...
# 52     If I were to buy a birthday cake in Vegas, thi...
# 57     After bookmarking this place I had to try. \n\...
# 65     Are you French... no??  THEN SHUT UP!!!  Who r...
# 66     After being here multiple times I'd say it's a...
# 68     Patisserie manon - why are you 25mi from my ho...
# 72     Watch out bookmarks, I am beginning to blow th...
# 73     Picked up a loaf of bread and a couple yummy m...
# 77     A nice french bakery, pastry, and bistro on th...
# 91     Looks like our search for good French Macrons ...
# 102    ETHNIC BAKERY TOUR  #2-FRANCE\n\nI have been a...
# 103    As someone who loves macarons and French cuisi...
# 105    This was down the street from our house and no...
# 106    This place is so sweet. I love it. \n\nI am ha...
# 109    Great place.  I hope it makes it.  I've sample...
# 116    I wish this place was closer!  Then again, wou...
# 129    Oh, you had me at French Macaron!\n\nI was ple...
# 131    I've been twice to pick up treasures and bring...
# 132    Hit Manon several times since my January revie...
# 133    Yelp 100 Challenge * 19/100\n\nYes, you can be...
# 134    Merci Beaucoup Patisserie Manon for the 15% Mi...
# ...                                                  ...
# 11738  the best breakfast place i've been to in my 27...
# 11747  Service is absolutely horrible here. Had to fl...
# 11764  2nd time here and I don't think we'll be back....
# 11768  The portions here are huge, but the food is ta...
# 11789  Before hitting up Marquee Night Club (on Party...
# 11806  Holstein's is a great option! \n\nIt's definit...
# 11817  Updating once again based on experiencing the ...
# 11834  5 stars for the food, 2 stars for the service....
# 11873  Hello Lobster Mac N Cheese you are my friend! ...
# 11885  I am debating between giving this place a 3 or...
# 11904  Rule No. 1:  Don't piss me off before I even g...
# 11942  Love Holsteins! Every time we plan a party nig...
# 11951  This place was packed at 5pm on a Saturday eve...
# 11959  Late night shake craving brought me in. It was...
# 11990  Oh my god. I've been wanting to try this for a...
# 11995  (Also located in Imperial Palace and M-Resort)...
# 11998  Came in for an early dinner since on was on th...
# 12001  Had the chicken and waffles, and it was not as...
# 12010  I'm not understanding the rave reviews of the ...
# 12024  "Beast Warrior Proportions".\n\nThat's the bes...
# 12048  When God appointed Gluttony as a sin. He was e...
# 12068  I've been to this place nearly a dozen times a...
# 12082  A cardinal sin was committed at Holsteins: I d...
# 12092  It all started with The Drunken Monkey which p...
# 12095  Talk about gourmet burger! Very creative conce...
# 12102  Kinda on the fence, but for now I will give 3 ...
# 12165  Being a restaurant at The Cosmopolitan I had p...
# 12180  Another featured burger in the "Vegas Seven" M...
# 12182  Wow!!!  Yummy burgers and delicious adult shak...
# 12184  Stopped by here for dinner after finding it im...
#
#                       user_id             business_id  stars  cluster
# 5      -594af_E7Z9VVjQc9pJK3g  A0X1baHPgw9IiBRivu0G9g    5.0       13
# 19     TdYKJgSgY2GF_YJnwsi5yQ  A0X1baHPgw9IiBRivu0G9g    4.0       13
# 22     y3FcL4bLy0eLlkb0SDPnBQ  A0X1baHPgw9IiBRivu0G9g    5.0       13
# 23     rHgT6lBbZ2PaHt0UWfTMtw  A0X1baHPgw9IiBRivu0G9g    5.0       13
# 28     FIk4lQQu1eTe2EpzQ4xhBA  A0X1baHPgw9IiBRivu0G9g    5.0       13
# 31     k4M43lXJuQMpQW65DTqzIQ  A0X1baHPgw9IiBRivu0G9g    4.0       13
# 34     7HOTOydGS7wJYaJqNoDfeg  A0X1baHPgw9IiBRivu0G9g    4.0       13
# 38     5OllWsrKJsYo3XQK6siRKA  A0X1baHPgw9IiBRivu0G9g    5.0       13
# 42     _i3IZYU28R3xgV4hxkmKjw  A0X1baHPgw9IiBRivu0G9g    5.0       13
# 47     fxrQSMhHlBv6eJVRdchG9Q  A0X1baHPgw9IiBRivu0G9g    5.0       13
# 52     Apj8bnqWlnaiSu4YDl0wDA  A0X1baHPgw9IiBRivu0G9g    4.0       13
# 57     iS4NVHLQDt1IzmmMKqwy5A  A0X1baHPgw9IiBRivu0G9g    4.0       13
# 65     jX7n6KfNZ22kBh6AHhxRbA  A0X1baHPgw9IiBRivu0G9g    5.0       13
# 66     3MO--ENqKScLFQFuW1751g  A0X1baHPgw9IiBRivu0G9g    3.0       13
# 68     dsaj_eA71FvpUh49zzKcGA  A0X1baHPgw9IiBRivu0G9g    5.0       13
# 72     N3oNEwh0qgPqPP3Em6wJXw  A0X1baHPgw9IiBRivu0G9g    5.0       13
# 73     0KeT9NKimYkHN0wlrij-dg  A0X1baHPgw9IiBRivu0G9g    4.0       13
# 77     Ksp1e9Dw0Jcog_ZBD3-45g  A0X1baHPgw9IiBRivu0G9g    4.0       13
# 91     77lef7kKkoOVupY-7AmieQ  A0X1baHPgw9IiBRivu0G9g    5.0       13
# 102    3nDUQBjKyVor5wV0reJChg  A0X1baHPgw9IiBRivu0G9g    4.0       13
# 103    tH0uKD-vNwMoEc3Xk3Cbdg  A0X1baHPgw9IiBRivu0G9g    4.0       13
# 105    VZRxANvyTm2ixS6jYDGgEw  A0X1baHPgw9IiBRivu0G9g    5.0       13
# 106    hZfzVrhsCQ9JDAb2jYoJNQ  A0X1baHPgw9IiBRivu0G9g    5.0       13
# 109    qbq4zC9SrZuaQ4-J-wtRuw  A0X1baHPgw9IiBRivu0G9g    4.0       13
# 116    b_9bJ2YjHbbvAob56f6U7A  A0X1baHPgw9IiBRivu0G9g    5.0       13
# 129    UYcmGbelzRa0Q6JqzLoguw  A0X1baHPgw9IiBRivu0G9g    5.0       13
# 131    DPtOaWemjBPvFiZJBi0m8A  A0X1baHPgw9IiBRivu0G9g    4.0       13
# 132    N044aCKJv3G5WuvwT5AJcA  A0X1baHPgw9IiBRivu0G9g    4.0       13
# 133    QJMOgjRYeogK43kyfX6PKw  A0X1baHPgw9IiBRivu0G9g    4.0       13
# 134    uEvusDwoSymbJJ0auR3muQ  A0X1baHPgw9IiBRivu0G9g    5.0       13
# ...                       ...                     ...    ...      ...
# 11738  Nw6Jza_cb0aqd4PT769Vzw  g8OnV26ywJlZpezdBnOWUQ    3.0        9
# 11747  -ouzfV5nm0Fmv3JRLXegmQ  g8OnV26ywJlZpezdBnOWUQ    2.0        9
# 11764  0KeT9NKimYkHN0wlrij-dg  g8OnV26ywJlZpezdBnOWUQ    2.0        9
# 11768  zBi_JWB5uUdVuz3JLoAxGQ  g8OnV26ywJlZpezdBnOWUQ    4.0        9
# 11789  oDyEexUT09e3XhxIp0-Wxg  P7pxQFqr7yBKMMI2J51udw    4.0        8
# 11806  6NYDXzkyYW3O2zYjzPRMsg  P7pxQFqr7yBKMMI2J51udw    4.0        8
# 11817  hZfzVrhsCQ9JDAb2jYoJNQ  P7pxQFqr7yBKMMI2J51udw    5.0        8
# 11834  c2MQ_LPuvtiiKFR_-OY9pg  P7pxQFqr7yBKMMI2J51udw    2.0        8
# 11873  8QKrhvVqhEkD8xo4E4s0GQ  P7pxQFqr7yBKMMI2J51udw    4.0        8
# 11885  UYcmGbelzRa0Q6JqzLoguw  P7pxQFqr7yBKMMI2J51udw    4.0        8
# 11904  m-BZLIIh5PCAKnzH0qj_0Q  P7pxQFqr7yBKMMI2J51udw    4.0        8
# 11942  z8wN6EQuw_JF-zTjcNgsLw  P7pxQFqr7yBKMMI2J51udw    5.0        8
# 11951  YVQFzWm0H72mLUh-8gzd5w  P7pxQFqr7yBKMMI2J51udw    3.0        8
# 11959  o4tYl3Hz0oDfpNn4k02DCw  P7pxQFqr7yBKMMI2J51udw    4.0        8
# 11990  Nhk0jTP2gkU12G4LHJVR3A  g8OnV26ywJlZpezdBnOWUQ    5.0        9
# 11995  hkSiQAfl6w3882JJQzRTlQ  g8OnV26ywJlZpezdBnOWUQ    5.0        9
# 11998  o4tYl3Hz0oDfpNn4k02DCw  g8OnV26ywJlZpezdBnOWUQ    3.0        9
# 12001  VZRxANvyTm2ixS6jYDGgEw  g8OnV26ywJlZpezdBnOWUQ    2.0        9
# 12010  qbq4zC9SrZuaQ4-J-wtRuw  g8OnV26ywJlZpezdBnOWUQ    2.0        9
# 12024  H3wPBzQCKCKiHcV7GZK4kg  g8OnV26ywJlZpezdBnOWUQ    5.0        9
# 12048  UvY0E6Wuhv_0Bita52RPOw  g8OnV26ywJlZpezdBnOWUQ    4.0        9
# 12068  kmE8w5Y785eZmodsx0V6Ag  P7pxQFqr7yBKMMI2J51udw    4.0        8
# 12082  ugNQV0isqQSAuuGzoK87sQ  P7pxQFqr7yBKMMI2J51udw    4.0        8
# 12092  Sv48jgljDP-CRfXmU8uSgA  P7pxQFqr7yBKMMI2J51udw    3.0        8
# 12095  Nbr4DYLPxURjxelLVTSt8A  P7pxQFqr7yBKMMI2J51udw    4.0        8
# 12102  SfY0jEFqBkrqq9bVi6P31Q  P7pxQFqr7yBKMMI2J51udw    3.0        8
# 12165  hulIBBzPsCaQDcoh_JgSBA  P7pxQFqr7yBKMMI2J51udw    1.0        8
# 12180  mY3mROf28N-vY1fpR-FFUw  P7pxQFqr7yBKMMI2J51udw    3.0        8
# 12182  1dWLN4Mr4hKhu8MQUCKqXQ  P7pxQFqr7yBKMMI2J51udw    4.0        8
# 12184  iAevEfcmtCr2cpd6IRqnTA  P7pxQFqr7yBKMMI2J51udw    4.0        8
#
# [1000 rows x 5 columns]

# %%
# size of each cluster
df2['cluster'].value_counts()
# Out:
# 18    5325
# 1     5035
# 2     3605
# 9     3415
# 14    3050
# 15    2796
# 3     2792
# 10    2738
# 8     2697
# 17    2591
# 13    2475
# 7     2396
# 0     1876
# 5     1846
# 4     1747
# 11    1424
# 12    1192
# 16    1049
# 19     791
# 6      506
# Name: cluster, dtype: int64

# %%
business_cluster_mostcount = df2['cluster'].groupby(df2['business_id']).agg(lambda x:x.value_counts().index[0])
len(business_cluster_mostcount)
# Out:
# 1620

# %%
label = business_cluster_mostcount.tolist()
len(label)
# Out:
# 1620

# %%
business_cluster = {'business_id': unique_business, 'cluster': label}
df_business_cluster = pd.DataFrame(business_cluster, columns = {'business_id', 'cluster'})
df_business_cluster.head(10)
# Out:
#    cluster             business_id
# 0       15  a192hdM0_UVCYLwPJv1Qwg
# 1        1  dVhGY-mNwTWQzK01Zxuclw
# 2        4  9_OPjioLbD9Q_zAeHfv6kw
# 3       10  DLJCwHGtbAV31UQ1lnIjlw
# 4        7  xiAiahsdBfTxYCFfvZmMfQ
# 5       10  DbEszO3wk1xVmN3pCPob2g
# 6        7  dQ4pxV6AxBaD3X4gssg5zg
# 7       16  tJ9-u9MfpVbX4X2miIJ71w
# 8       14  x71EvWJDVKZfM-OiYDWZ6A
# 9       15  ZCQa7CJxZ-53Zxd_pobWug

# %%
df_business_cluster['cluster'].value_counts()
# Out:
# 18    177
# 1     159
# 14    133
# 2     113
# 3     108
# 9     103
# 7      90
# 15     84
# 8      78
# 10     77
# 5      72
# 13     68
# 17     66
# 4      61
# 0      57
# 12     48
# 11     45
# 16     30
# 19     30
# 6      21
# Name: cluster, dtype: int64

# %%
##### BASELINE for RC and UC #####
rc_score = []
uc_score = []


from pandas import merge
for i in range(1):
    from random import randint
    restaurant_cluster_random = []
    user_cluster_random = []
    for i in range(len(unique_business)):
        restaurant_cluster_random.append(randint(0,K_CLUSTERS_RESTAURANT))
    
    #for i in range(len(top_users)):
    #    user_cluster_random.append(randint(0,K_CLUSTERS_USER))

    temp_business = df_business_cluster
    #temp_user = df_user_cluster
    temp_business['restaurant_cluster_random'] = restaurant_cluster_random
    #temp_user['user_cluster_random'] = user_cluster_random
    final = merge(df2, temp_business[['business_id', 'restaurant_cluster_random']],on='business_id')
    #final = merge(df2, temp_user[['user_id', 'user_cluster_random']],on='user_id')

    #Restuarant Cluster Evaluation Metric (baseline)
    mse_restaurant = [0] * K_CLUSTERS_RESTAURANT;

    for restaurant in unique_business:
        for cluster in range(K_CLUSTERS_RESTAURANT):
            ratings = final[final['business_id']==restaurant][final['restaurant_cluster_random']==cluster]['stars']
            if len(ratings) > 1:
                mean = sum(ratings) / len(ratings)
                mse = sum((ratings - mean) ** 2)
                mse_restaurant[cluster] += mse

    # User Cluster Evaluation Metric (baseline)
    #mse_user = [0] * K_CLUSTERS_USER;

    #for restaurant in unique_business:
     #   for cluster in range(K_CLUSTERS_USER):
      #      ratings = final[final['business_id']==restaurant][final['user_cluster_random']==cluster]['stars']
       #     if len(ratings) > 1:
        #        mean = sum(ratings) / len(ratings)
         #       mse = sum((ratings - mean) ** 2)
          #      mse_user[cluster] += mse

    rc_score.append(sum(mse_restaurant))
    #uc_score.append(sum(mse_user))
    
baseline_rc = sum(rc_score)/len(rc_score)
#baseline_uc = sum(uc_score)/len(uc_score)
print(baseline_rc)
#print(baseline_uc)
# Out:
# /home/ubuntu/.local/lib/python3.5/site-packages/ipykernel_launcher.py:29: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# 41585.3222055

# %%
##### Current Score for RC and UC #####
mse_restaurant = [0] * K_CLUSTERS_RESTAURANT;

for restaurant in unique_business:
    for cluster in range(K_CLUSTERS_RESTAURANT):
        ratings = df2[df2['business_id']==restaurant][df2['cluster']==cluster]['stars']
        if len(ratings) > 1:
            mean = sum(ratings) / len(ratings)
            mse = sum((ratings - mean) ** 2)
            mse_restaurant[cluster] += mse


#mse_user = [0] * K_CLUSTERS_USER;

#for restaurant in unique_business:
 #   for cluster in range(K_CLUSTERS_USER):
  #      ratings = df2[df2['business_id']==restaurant][df2['cluster']==cluster]['stars']
   #     
    #    if len(ratings) > 1:
     #       mean = sum(ratings) / len(ratings)
      #      mse = sum((ratings - mean) ** 2)
       #     mse_user[cluster] += mse

            
current_rc = sum(mse_restaurant)
#current_uc = sum(mse_user)
print(current_rc)
#print(current_uc)
# Out:
# /home/ubuntu/.local/lib/python3.5/site-packages/ipykernel_launcher.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# 43934.6818751
